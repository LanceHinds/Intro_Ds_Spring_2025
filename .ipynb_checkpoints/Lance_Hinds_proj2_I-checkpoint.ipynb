# %% [markdown]
# Name: Lance Hinds
#
# Student ID: @03045386

# %% [markdown]
# Title: Happiness Data Set Analysis

# %% [markdown]
# Introduction:
# This jupyter notebook will analyze data taken from a happiness dataset.  The happiness dataset inlcudes factors that determine the happienss rank of a given country.  Due to the large amount of numerical data present in this dataset, an additional category of numerical data was added to the dataset (the Development Level category).  The dataset will be sufficient for observation with a balance of numerical and categorical data.

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Happiness_2015_updated.csv') #load dataset

# %%
df
# Out:
#      Unnamed: 0      Country                           Region  Happiness Rank  \
# 0             0  Switzerland                   Western Europe               1
# 1             1      Iceland                   Western Europe               2
# 2             2      Denmark                   Western Europe               3
# 3             3       Norway                   Western Europe               4
# 4             4       Canada                    North America               5
# ..          ...          ...                              ...             ...
# 153         153       Rwanda               Sub-Saharan Africa             154
# 154         154        Benin               Sub-Saharan Africa             155
# 155         155        Syria  Middle East and Northern Africa             156
# 156         156      Burundi               Sub-Saharan Africa             157
# 157         157         Togo               Sub-Saharan Africa             158
#
# ...

# %% [markdown]
# #### Section 1

# %%
#1
df.shape
# Out:
# (158, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     158 non-null    int64
#  1   Country                        158 non-null    object
#  2   Region                         158 non-null    object
#  3   Happiness Rank                 158 non-null    int64
#  4   Happiness Score                158 non-null    float64
#  5   Standard Error                 158 non-null    float64
#  6   Economy (GDP per Capita)       158 non-null    float64
#  7   Family                         158 non-null    float64
#  8   Health (Life Expectancy)       158 non-null    float64
#  9   Freedom                        158 non-null    float64
#  10  Trust (Government Corruption)  158 non-null    float64
#  11  Generosity                     158 non-null    float64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0      Country          Region  Happiness Rank  Happiness Score  \
# 0           0  Switzerland  Western Europe               1            7.587
# 1           1      Iceland  Western Europe               2            7.561
# 2           2      Denmark  Western Europe               3            7.527
# 3           3       Norway  Western Europe               4            7.522
# 4           4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  Country                           Region  Happiness Rank  \
# 153         153   Rwanda               Sub-Saharan Africa             154
# 154         154    Benin               Sub-Saharan Africa             155
# 155         155    Syria  Middle East and Northern Africa             156
# 156         156  Burundi               Sub-Saharan Africa             157
# 157         157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
#2
df.dtypes
# Out:
# Unnamed: 0                         int64
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# Developmemt Level                 object
# dtype: object

# %%
#3
df.isnull()
#There are no missing values in the dataset
# Out:
#      Unnamed: 0  Country  Region  Happiness Rank  Happiness Score  \
# 0         False    False   False           False            False
# 1         False    False   False           False            False
# 2         False    False   False           False            False
# 3         False    False   False           False            False
# 4         False    False   False           False            False
# ..          ...      ...     ...             ...              ...
# 153       False    False   False           False            False
# 154       False    False   False           False            False
# 155       False    False   False           False            False
# 156       False    False   False           False            False
# 157       False    False   False           False            False
#
#      Standard Error  Economy (GDP per Capita)  Family  \
# 0             False                     False   False
# 1             False                     False   False
# ...

# %% [markdown]
# The dataset consists of factors of happiness for each country.  Some of these factors involve the economy, health, and freedom of the country.

# %% [markdown]
# #### Section 2

# %%
#4
df.duplicated().sum() 
#There aren't duplicates
# Out:
# 0

# %%
#5
df[['Happiness Score','Economy (GDP per Capita)']] #print two important takeaways from the dataset
# Out:
#      Happiness Score  Economy (GDP per Capita)
# 0              7.587                   1.39651
# 1              7.561                   1.30232
# 2              7.527                   1.32548
# 3              7.522                   1.45900
# 4              7.427                   1.32629
# ..               ...                       ...
# 153            3.465                   0.22208
# 154            3.340                   0.28665
# 155            3.006                   0.66320
# 156            2.905                   0.01530
# 157            2.839                   0.20868
#
# [158 rows x 2 columns]

# %%
df.loc[1] #print only data for 2nd entry in dataset (Iceland) (These commands will be essential in analyzing the dataset)
# Out:
# Unnamed: 0                                    1
# Country                                 Iceland
# Region                           Western Europe
# Happiness Rank                                2
# Happiness Score                           7.561
# Standard Error                          0.04884
# Economy (GDP per Capita)                1.30232
# Family                                  1.40223
# Health (Life Expectancy)                0.94784
# Freedom                                 0.62877
# Trust (Government Corruption)           0.14145
# Generosity                               0.4363
# Dystopia Residual                       2.70201
# Developmemt Level                          High
# Name: 1, dtype: object

# %% [markdown]
# #### Section 3

# %%
#6
df.describe()
# Out:
#        Unnamed: 0  Happiness Rank  Happiness Score  Standard Error  \
# count  158.000000      158.000000       158.000000      158.000000
# mean    78.500000       79.493671         5.375734        0.047885
# std     45.754781       45.754363         1.145010        0.017146
# min      0.000000        1.000000         2.839000        0.018480
# 25%     39.250000       40.250000         4.526000        0.037268
# 50%     78.500000       79.500000         5.232500        0.043940
# 75%    117.750000      118.750000         6.243750        0.052300
# max    157.000000      158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# ...

# %% [markdown]
# One interesting insight that can be seen from this data is that one country has a GDP per Capita of zero.  This will be very eesential in determining the happiness rank of that country.

# %%
#7
df.value_counts()
# Out:
# Unnamed: 0  Country      Region                           Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  Family   Health (Life Expectancy)  Freedom  Trust (Government Corruption)  Generosity  Dystopia Residual  Developmemt Level
# 0           Switzerland  Western Europe                   1               7.587            0.03411         1.39651                   1.34951  0.94143                   0.66557  0.41978                        0.29678     2.51738            High                 1
# 108         Bangladesh   Southern Asia                    109             4.694            0.03077         0.39753                   0.43106  0.60164                   0.40820  0.12569                        0.21222     2.51767            Low                  1
# ...

# %%
#8
Development_grouped=df.groupby('Developmemt Level')['Country'].count() #number of countries with each development level
Development_grouped
# Out:
# Developmemt Level
# High          40
# Low           40
# Low Middle    39
# Middle        39
# Name: Country, dtype: int64

# %%
Region_grouped=df.groupby('Developmemt Level')['Economy (GDP per Capita)'].mean() #the average GDP for each development level
Region_grouped
# Out:
# Developmemt Level
# High          1.321492
# Low           0.284361
# Low Middle    0.743333
# Middle        1.037579
# Name: Economy (GDP per Capita), dtype: float64

# %% [markdown]
# #### Section 4

# %% [markdown]
# 9.  A pattern that was noticed when analyzing the data was that each level of the development level consisted of around the same amount of countries.  An important takeaway from the dataset was that some of the data types are objects instead of strings or integers (this could cause a problem when further utilizing the data set).
# 10.
#     1. How will using different data types affect the use of sorting and math functions?
#     2. Is there other data (categorical or numerical) that can be determined based on the statitsics gathered from the obeservations in this part of the project?

# %% [markdown]
# Conclusion: The components of the dataset were thoroughly observed in this part of the project.  Multiple commands for sorting and filtering the data were used and trends were seen from this analysis.  The assignment provided a greater understanding of the dataset, providing guidance on future uses of the dataset.

# %%
#clean dataset
df_cleaned=df.copy()
df_cleaned.to_csv('Happiness_2015_updated_cleaned.csv')

# %% [markdown]
# References: https://www.kaggle.com/datasets/unsdsn/world-happiness
